# %%
#Testing loading model
from detectron2.modeling import build_model
from mask2former import add_maskformer2_config
from detectron2.config import get_cfg
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/1g/k9xfmv_s29vf0f5bf06smtn00000gn/T/ipykernel_74534/3309371676.py in <module>
#       1 #Testing loading model
#       2 from detectron2.modeling import build_model
# ----> 3 from mask2former import add_maskformer2_config
#       4 from detectron2.config import get_cfg
#
# ~/repositories/wsobjdet/mask2former/__init__.py in <module>
#       1 # Copyright (c) Facebook, Inc. and its affiliates.
#       2 from . import data  # register all new datasets
# ----> 3 from . import modeling
#       4
#       5 # config
#
# ~/repositories/wsobjdet/mask2former/modeling/__init__.py in <module>
#       1 # Copyright (c) Facebook, Inc. and its affiliates.
#       2 from .backbone.swin import D2SwinTransformer
# ----> 3 from .pixel_decoder.fpn import BasePixelDecoder
# ...

# %%
cfg = get_cfg()
add_maskformer2_config(cfg)
print(cfg)
# !pwd
# !ls configs/
# !cat configs/maskformer2_R50_bs16_50ep.yaml
cfg.merge_from_file('configs/maskformer2_R50_bs16_50ep.yaml')
print(cfg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/1g/k9xfmv_s29vf0f5bf06smtn00000gn/T/ipykernel_74534/418840811.py in <module>
#       1 cfg = get_cfg()
# ----> 2 add_maskformer2_config(cfg)
#       3 print(cfg)
#       4 get_ipython().system('pwd')
#       5 get_ipython().system('ls configs/')
#
# NameError: name 'add_maskformer2_config' is not defined

# %%
from iopath import PathManager
pathmanager = PathManager()

# %%
print(pathmanager)

# %%
pathmanager.isfile('configs/maskformer2_R50_bs16_50ep.yaml')
print(pathmanager.open('configs/maskformer2_R50_bs16_50ep.yaml', "r"))
# Out:
# <_io.TextIOWrapper name='configs/maskformer2_R50_bs16_50ep.yaml' mode='r' encoding='UTF-8'>
